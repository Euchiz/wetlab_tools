# %%
# script for extracting ANTECH CBC info from pdf
# based on pdfplumber @https://github.com/jsvine/pdfplumber
# by Zac Zou

# modules required
import numpy as np
import pandas as pd
import pdfplumber

# open results in pdf
file = "SD23-1-1 to SD23-1-41 CBC Y2300229.pdf"
pdf = pdfplumber.open(file)

# items blacklist
items_black = ['Differential', 'Blood Parasites', 'Platelet Estimate']

# initialize results dataframe
result = pd.DataFrame()

# collect info page by page
for i in range(len(pdf.pages)):
    page = pdf.pages[i]
    
    # crop the page into 2 parts that contain tables
    ID = page.crop(
        (0.16*float(page.width), 0.168*float(page.height), 0.24*float(page.width), 0.182*float(page.height))
        ).extract_text()
    info = page.crop(
        (0.072*float(page.width), 0.245*float(page.height), 0.5*float(page.width), 0.7*float(page.height))
        ).extract_text(layout = True).split('\n')
    
    # normalize info format
    try: tail_index = info.index('Comment                             ')
    except ValueError:
        print(f'Skipping page {i+1}, which is not in a standard format. Consider entering the values manually. \n(Mice ID: {ID})')
        continue
    info = info[:tail_index]
        
    # add collected info to dataframe
    info_dict = {}
    for count in info: 
        # collect info by line
        count_list = count.split('  ', 1)
        key = count_list[0].strip()
        try: value = [n.strip() for n in ''.join(count_list[1].strip().split(',')).split('  ', 1)]
        except IndexError: continue
        if key in items_black: continue
        # write into dataframe
        if len(value) == 1:
            info_dict[key] = value[0]
        elif len(value) == 2:
            info_dict[key+' (absolute)'] = value[0]
            info_dict[key+' (percentage)'] = value[1]        
    result[ID] = info_dict
        
# final clean-up
result.replace('', np.nan, inplace = True)
result.dropna(inplace = True)
result.to_excel(file.strip('.pdf') + '.xlsx')
print(f'\nDataframe generated. Excel file exported. ')
result
# Out:
# Dataframe generated. Excel file exported.
#                            Sd23-1-1   Sd23-1-2   Sd23-1-3   Sd23-1-4
# WBC                       3.1 (LOW)  4.9 (LOW)  1.2 (LOW)  3.6 (LOW)  \
# RBC                             7.9        7.9        9.1        9.0
# HGB                            14.1       14.7       14.1       15.5
# HCT                              48         48         49  55 (HIGH)
# MCV                              61         61         54         61
# MCH                            17.8       18.6       15.4       17.1
# MCHC                             29         31         29         28
# Platelet Count                 2450       2576        675       2178
# Neutrophils (absolute)          434        931        228        180
# Neutrophils (percentage)         14         19         19          5
# Bands                             0          0          0          0
# Lymphocytes (absolute)         2356       3675        864       3348
# Lymphocytes (percentage)         76         75         72         93
# Monocytes (absolute)            248        196         84         36
# Monocytes (percentage)            8          4          7          1
# Eosinophils (absolute)           62         98         24         36
# Eosinophils (percentage)          2          2          2          1
# Basophils (absolute)              0          0          0          0
# Basophils (percentage)            0          0          0          0
#
#                            Sd23-1-5   Sd23-1-6   Sd23-1-7 Sd23-1-8   Sd23-1-9
# WBC                       3.9 (LOW)        6.6        5.5      5.6  4.7 (LOW)  \
# RBC                             9.7        8.7        9.5      8.8        8.5
# HGB                            15.1       14.6       14.6     14.1       14.6
# HCT                       53 (HIGH)  52 (HIGH)  51 (HIGH)       50  51 (HIGH)
# MCV                              55         60         54       57         59
# MCH                            15.6       16.8       15.4     16.0       17.1
# MCHC                             29         28         28       28         29
# Platelet Count                 1698       2098       1870     1985       2969
# Neutrophils (absolute)          195        198        220      280        188
# Neutrophils (percentage)          5          3          4        5          4
# Bands                             0          0          0        0          0
# Lymphocytes (absolute)         3588       6006       5060     5208       4371
# Lymphocytes (percentage)         92         91         92       93         93
# Monocytes (absolute)             39        396        165      112        141
# Monocytes (percentage)            1          6          3        2          3
# Eosinophils (absolute)           78          0         55        0          0
# Eosinophils (percentage)          2          0          1        0          0
# Basophils (absolute)              0          0          0        0          0
# Basophils (percentage)            0          0          0        0          0
#
#                           Sd23-1-10  ...  Sd23-1-32  Sd23-1-33  Sd23-1-34
# WBC                       5.4 (LOW)  ...        7.1  5.2 (LOW)        7.2  \
# RBC                             8.0  ...        8.7        8.9        8.8
# HGB                            13.5  ...       14.2       15.2       15.4
# HCT                              49  ...  51 (HIGH)  53 (HIGH)  53 (HIGH)
# MCV                              61  ...         59         59         61
# MCH                            16.8  ...       16.2       17.0       17.7
# MCHC                             28  ...         28         29         29
# Platelet Count                 2258  ...       2194       2802       2251
# Neutrophils (absolute)          324  ...        568        312        576
# Neutrophils (percentage)          6  ...          8          6          8
# Bands                             0  ...          0          0          0
# Lymphocytes (absolute)         4914  ...       6319       4784       6552
# Lymphocytes (percentage)         91  ...         89         92         91
# Monocytes (absolute)            108  ...        213        104         72
# Monocytes (percentage)            2  ...          3          2          1
# Eosinophils (absolute)           54  ...          0          0          0
# Eosinophils (percentage)          1  ...          0          0          0
# Basophils (absolute)              0  ...          0          0          0
# Basophils (percentage)            0  ...          0          0          0
#
#                           Sd23-1-35  Sd23-1-36  Sd23-1-37  Sd23-1-38
# WBC                            10.8  5.4 (LOW)        7.6        9.1  \
# RBC                             8.7        9.3        8.7        8.6
# HGB                            14.8       15.4       15.4       15.3
# HCT                       52 (HIGH)  54 (HIGH)  52 (HIGH)  52 (HIGH)
# MCV                              60         58         60         60
# MCH                            16.9       16.6       17.8       17.8
# MCHC                             28         29         30         30
# Platelet Count                 1484       2168       2882       3387
# Neutrophils (absolute)          108        270        380        819
# Neutrophils (percentage)          1          5          5          9
# Bands                             0          0          0          0
# Lymphocytes (absolute)        10476       5130       6992       7826
# Lymphocytes (percentage)         97         95         92         86
# Monocytes (absolute)            216          0        228        455
# Monocytes (percentage)            2          0          3          5
# Eosinophils (absolute)            0          0          0          0
# Eosinophils (percentage)          0          0          0          0
# Basophils (absolute)              0          0          0          0
# Basophils (percentage)            0          0          0          0
#
#                             Sd23-1-39  Sd23-1-40  Sd23-1-41
# WBC                       11.4 (HIGH)       11.0        7.1
# RBC                               8.6        8.7        9.8
# HGB                              15.0       14.3       15.7
# HCT                         53 (HIGH)  52 (HIGH)  55 (HIGH)
# MCV                                62         60         56
# MCH                              17.4       16.5       16.0
# MCHC                               28         27         28
# Platelet Count                   2004       1268       1830
# Neutrophils (absolute)            570        660        568
# Neutrophils (percentage)            5          6          8
# Bands                               0          0          0
# Lymphocytes (absolute)          10260      10120       6461
# Lymphocytes (percentage)           90         92         91
# Monocytes (absolute)              570        220         71
# Monocytes (percentage)              5          2          1
# Eosinophils (absolute)              0          0          0
# Eosinophils (percentage)            0          0          0
# Basophils (absolute)                0          0          0
# Basophils (percentage)              0          0          0
#
# [19 rows x 41 columns]
